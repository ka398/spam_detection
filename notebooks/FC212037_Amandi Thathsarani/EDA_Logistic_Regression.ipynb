# %% [markdown]
# Import Libraries & Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %% [markdown]
# Load & Preview the Data

# %%
#load and read the dataset
df = pd.read_csv("../../data/maildata.csv")
# df = pd.read_csv("../../data/spam_Emails_data.csv")


#print the first few rows
print(df.head())
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Check Data info and Missing Values

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB
# None
# Category    0
# Message     0
# dtype: int64

# %% [markdown]
# Count messages are spam or ham

# %%
# Print columns to see what the actual label column is called
print("Columns in dataset:", df.columns)

# If 'Category' column does not exist, try to find and rename the correct column
if 'Category' not in df.columns:
    # Example: If the column is called 'label' or something similar, rename it
    if 'label' in df.columns:
        df.rename(columns={'label': 'Category'}, inplace=True)
    elif 'type' in df.columns:
        df.rename(columns={'type': 'Category'}, inplace=True)
    # Add more conditions as needed depending on your new dataset
# Out:
# Columns in dataset: Index(['Category', 'Message'], dtype='object')

# %%
df.rename(columns={'label': 'Category'}, inplace=True)

print(df['Category'].unique())

# Convert to lowercase safely and map
df['Category'] = df['Category'].astype(str).str.lower().map({'spam': 0, 'ham': 1})

# Now print counts
print("Total email messaages: ", len(df))
print("Spam email messages: ", df[df['Category'] == 0].shape[0])
print("Ham email messages: ", df[df['Category'] == 1].shape[0])
# Out:
# ['ham' 'spam']
# Total email messaages:  5572
# Spam email messages:  747
# Ham email messages:  4825

# %% [markdown]
# Visualize Distribution

# %%
sns.countplot(x='Category', data=df)
plt.xticks([0,1], ['Spam', 'Ham'])
plt.title("Spam vs Ham Message Count")
plt.show()

# %% [markdown]
# Message Length Analysis

# %%
df.rename(columns={'text': 'Message'}, inplace=True) 

if 'length' not in df.columns:  # 👈 ADD THIS
    df['length'] = df['Message'].astype(str).apply(len)

#basic stats of message length
print(df.groupby('Category')['length'].describe())

#length distribution by class
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='length', hue='Category', bins=50, kde=True, element='step')
plt.title("Message Length Distribution by Category")
plt.show()
# Out:
#            count        mean        std  min    25%    50%    75%    max
# Category
# 0          747.0  137.989290  29.980287  7.0  132.0  149.0  157.0  223.0
# 1         4825.0   71.448705  58.436848  2.0   33.0   52.0   93.0  910.0

# %% [markdown]
# Word Count Analysis

# %%
df['word_count'] = df['Message'].astype(str).apply(lambda x: len(x.split()))

print(df.groupby('Category')['word_count'].describe())
# Out:
#            count       mean        std  min   25%   50%   75%    max
# Category
# 0          747.0  23.812584   5.956923  1.0  22.0  25.0  28.0   35.0
# 1         4825.0  14.310259  11.517945  1.0   7.0  11.0  19.0  171.0

# %% [markdown]
# Most common words in Spam emails vs Ham emails

# %%
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def get_mostCommonWords(messages, stopwords=ENGLISH_STOP_WORDS, n=20):
    words = ' '.join(messages.astype(str)).lower().split()
    words = [word for word in words if word.isalpha() and word not in stopwords]
    return Counter(words).most_common(n)

# Apply function to spam and ham
spam_words = get_mostCommonWords(df[df['Category'] == 0]['Message'])
ham_words = get_mostCommonWords(df[df['Category'] == 1]['Message'])

# plotting function (your code)
def plot_top_words(word_list, title):
    words, counts = zip(*word_list)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(counts), y=list(words), color='steelblue')
    plt.title(title)
    plt.xlabel("Frequency")
    plt.ylabel("Words")
    plt.tight_layout()
    plt.show()

plot_top_words(spam_words, "Top 20 Spam Words")
plot_top_words(ham_words, "Top 20 Ham Words")

print("\nTop spam words:", spam_words)
print("\nTop ham words:", ham_words)
# Out:
# Top spam words: [('free', 180), ('ur', 144), ('txt', 136), ('u', 115), ('text', 112), ('mobile', 109), ('claim', 104), ('reply', 101), ('stop', 90), ('just', 76), ('new', 69), ('send', 66), ('nokia', 64), ('won', 61), ('win', 58), ('prize', 56), ('cash', 56), ('contact', 55), ('service', 48), ('customer', 40)]
#
# Top ham words: [('u', 881), ('just', 287), ('ur', 241), ('got', 228), ('like', 223), ('come', 218), ('know', 208), ('good', 189), ('going', 157), ('ü', 157), ('ok', 156), ('want', 154), ('love', 153), ('time', 153), ('need', 148), ('n', 137), ('r', 131), ('dont', 129), ('think', 124), ('send', 121)]
